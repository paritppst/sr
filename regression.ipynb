# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Creating a DataFrame
nescafe = pd.read_csv('./data.csv')

# %% [markdown]
# ## Regression
#
# #### 2 Models & Method : OLS
#     * 1. Multiple Linear Regression Model
#     * 2. MLR with Interaction terms (3-way)

# %%
regress_1st_model1 = ols("Qsold ~  S_follower + S_rating_count + S_score + P_price + P_score + P_rating_count + P_fav_count + t_pos_comments + t_neg_comments", data= nescafe).fit()
regression1 = regress_1st_model1.summary()
print(regression1)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Qsold   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                     3644.
# Date:                Mon, 17 May 2021   Prob (F-statistic):               0.00
# Time:                        04:03:03   Log-Likelihood:                -2561.9
# No. Observations:                 539   AIC:                             5144.
# Df Residuals:                     529   BIC:                             5187.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          0.9119      4.783      0.191      0.849      -8.484      10.308
# ...

# %% [markdown]
# ## Results

# %%
# summary statistic
statistic = nescafe.describe()
statistic
# Out:
#        S_rating_count     S_score     S_follower  S_variation  \
# count    5.390000e+02  539.000000     539.000000   539.000000
# mean     2.161822e+04    4.215584    3749.896104  1071.502783
# std      1.364958e+05    1.544621   15457.917347  1457.706696
# min      0.000000e+00    0.000000       0.000000     1.000000
# 25%      1.600000e+01    4.600000      11.500000   165.000000
# 50%      2.660000e+02    4.800000     187.000000   438.000000
# 75%      2.900000e+03    4.900000     762.000000  1200.000000
# max      1.200000e+06    5.900000  126500.000000  6900.000000
#
#        S_responserate_percent  S_joined_month      P_price        Qsold  \
# count              539.000000      539.000000   539.000000   539.000000
# mean                70.981447       24.320037   376.131725    49.437848
# std                 26.156798       17.586855   192.907771   222.851238
# min                  1.000000        0.500000    17.000000     0.000000
# ...

# %%
# Correlation

correlation = nescafe.corr(method='pearson')
correlation
